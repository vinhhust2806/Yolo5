# %% [markdown]
# # **HELMET DETECTION**

# %% [markdown]
# #Bước 2:Kết nối drive và copy data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !cp /content/drive/MyDrive/20220306-Objectdetection-TA-NDT/Helmet/data/Dataset.zip /content
# !unzip Dataset.zip
# Out:
# /content

# %% [markdown]
# # Bước 3: Clone YOLOv5 và cài đặt môi trường

# %%
cd /content/drive/MyDrive/20220306-Objectdetection-TA-NDT/Helmet
# Out:
# /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

# %% [markdown]
# #Bước 4: Thiết lập file yaml

# %%
import yaml

dict_file = {'train':'/content/Dataset/images/train' ,
            'val': '/content/Dataset/images/val',
            'nc' : '3',
            'names' : ['helmet','head','person']}

with open('data/Helmet.yaml', 'w+') as file:
    documents = yaml.dump(dict_file, file)

# %%
# # Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %% [markdown]
# #Bước 5: Training

# %%
# # Weights & Biases  (optional)
# %pip install -q wandb
# import wandb
# wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 70 --epochs 50 --data Helmet.yaml --weights yolov5s.pt --cache
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: Enter your choice: (30 second timeout) no
# wandb: WARNING Invalid choice
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=Helmet.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=70, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# #Bước 6: Test
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source '/content/Dataset/images/test'

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source 'data/Video2.mp4'
# Out:
# ...
# detect: weights=['runs/train/exp2/weights/best.pt'], source=data/Video2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-105-gd257c75 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/3277) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/Video2.mp4: 384x640 Done. (0.022s)
# video 1/1 (2/3277) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/Video2.mp4: 384x640 Done. (0.012s)
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source 'data/Video1.mp4'
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2689/7686) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/Video1.mp4: 384x640 Done. (0.010s)
# video 1/1 (2690/7686) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/Video1.mp4: 384x640 Done. (0.010s)
# video 1/1 (2691/7686) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/Video1.mp4: 384x640 Done. (0.009s)
# video 1/1 (2692/7686) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/Video1.mp4: 384x640 Done. (0.010s)
# video 1/1 (2693/7686) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/Video1.mp4: 384x640 Done. (0.009s)
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.5 --source 'data/video4.mkv'
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=data/video4.mkv, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-105-gd257c75 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/3684) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/video4.mkv: 384x640 Done. (0.024s)
# video 1/1 (2/3684) /content/drive/.shortcut-targets-by-id/1k6swrkn5rI92MyKL6gIndctJ7IJGV2xI/20220306-Objectdetection-TA-NDT/Helmet/yolov5/data/video4.mkv: 384x640 Done. (0.017s)
# ...
